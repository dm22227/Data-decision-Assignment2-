# %%
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
import glob

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls '/content/drive/MyDrive/Colab Notebooks/Stress_dataset'
# Out:
# 5C  6B	6D  7A	7E  8B

# %% [markdown]
# ## 5C Folder visualization

# %%
path2 =  r"/content/drive/MyDrive/Colab Notebooks/Stress_dataset/5C"
acc_data = pd.DataFrame()
bvp_data = pd.DataFrame()
EDA_data = pd.DataFrame()
T_data = pd.DataFrame()

# Loop through all the subdirectories and files in the directory
for root, dirs, files in os.walk(path2):
    for file in files:
        # Check if the file is a CSV file
        if file.endswith('ACC.csv'):
          # Read the CSV file 
          file_path = os.path.join(root, file)
          temp_data = pd.read_csv(file_path, header=None, nrows=100) # 100 features per folder
          # Append the DataFrame 
          acc_data = acc_data.append(temp_data, ignore_index=True)

acc_data.columns = ['ACC_x', 'ACC_y', 'ACC_z']


for root, dirs, files in os.walk(path2):
    for file in files:
        # Check if the file is a CSV file
        if file.endswith('BVP.csv'):
            # Read the CSV file 
            file_path = os.path.join(root, file)
            temp_data = pd.read_csv(file_path, header=None, nrows=100)
            # Append the DataFrame 
            bvp_data = bvp_data.append(temp_data, ignore_index=True)

bvp_data.columns = ['BVP']


for root, dirs, files in os.walk(path2):
    for file in files:
        # Check if the file is a CSV file
        if file.endswith('EDA.csv'):
            # Read the CSV file 
            file_path = os.path.join(root, file)
            temp_data = pd.read_csv(file_path, header=None,nrows=100)
            # Append the DataFrame 
            EDA_data = EDA_data.append(temp_data, ignore_index=True)
               



EDA_data.columns = ['EDA']


# Loop through all the subdirectories and files in the directory
for root, dirs, files in os.walk(path2):
    for file in files:
        # Check if the file is a CSV file
        if file.endswith('TEMP.csv'):
            # Read the CSV file 
            file_path = os.path.join(root, file)
            temp_data = pd.read_csv(file_path, header=None,nrows=100)
            # Append the DataFrame 
            T_data = T_data.append(temp_data, ignore_index=True)

T_data.columns = ['Temp']

C5_dataframe =pd.DataFrame()
C5_dataframe = pd.concat([acc_data, bvp_data, EDA_data, T_data], axis=1) # merging features

from sklearn.preprocessing import Normalizer
C5_col_names = list(C5_dataframe.columns)
C5_dataframe = Normalizer().fit_transform(C5_dataframe)
C5_dataframe = pd.DataFrame(C5_dataframe, columns=C5_col_names)

# Imports
import matplotlib.pyplot as plot
b_plot = C5_dataframe.boxplot(column = ['ACC_x', 'ACC_y', 'ACC_z','BVP','EDA','Temp']) 
b_plot.plot()
plot.show()

###Box plot for 5C folder

# %% [markdown]
# ## 6B Folder visualization

# %%
path3 =  r"/content/drive/MyDrive/Colab Notebooks/Stress_dataset/6B"
acc_data = pd.DataFrame()
bvp_data = pd.DataFrame()
EDA_data = pd.DataFrame()
T_data = pd.DataFrame()

# Loop through all the subdirectories and files in the directory
for root, dirs, files in os.walk(path3):
    for file in files:
        # Check if the file is a CSV file
        if file.endswith('ACC.csv'):
          # Read the CSV file 
          file_path = os.path.join(root, file)
          temp_data = pd.read_csv(file_path, header=None, nrows=100) # 100 features per folder
          # Append the DataFrame 
          acc_data = acc_data.append(temp_data, ignore_index=True)

acc_data.columns = ['ACC_x', 'ACC_y', 'ACC_z']


for root, dirs, files in os.walk(path3):
    for file in files:
        # Check if the file is a CSV file
        if file.endswith('BVP.csv'):
            # Read the CSV file 
            file_path = os.path.join(root, file)
            temp_data = pd.read_csv(file_path, header=None, nrows=100)
            # Append the DataFrame 
            bvp_data = bvp_data.append(temp_data, ignore_index=True)

bvp_data.columns = ['BVP']


for root, dirs, files in os.walk(path3):
    for file in files:
        # Check if the file is a CSV file
        if file.endswith('EDA.csv'):
            # Read the CSV file 
            file_path = os.path.join(root, file)
            temp_data = pd.read_csv(file_path, header=None,nrows=100)
            # Append the DataFrame 
            EDA_data = EDA_data.append(temp_data, ignore_index=True)
               



EDA_data.columns = ['EDA']


# Loop through all the subdirectories and files in the directory
for root, dirs, files in os.walk(path3):
    for file in files:
        # Check if the file is a CSV file
        if file.endswith('TEMP.csv'):
            # Read the CSV file 
            file_path = os.path.join(root, file)
            temp_data = pd.read_csv(file_path, header=None,nrows=100)
            # Append the DataFrame 
            T_data = T_data.append(temp_data, ignore_index=True)

T_data.columns = ['Temp']

B6_dataframe =pd.DataFrame()
B6_dataframe = pd.concat([acc_data, bvp_data, EDA_data, T_data], axis=1) # merging features

from sklearn.preprocessing import Normalizer
B6_col_names = list(B6_dataframe.columns)
B6_dataframe = Normalizer().fit_transform(B6_dataframe)
B6_dataframe = pd.DataFrame(B6_dataframe, columns=B6_col_names)

# Imports
import matplotlib.pyplot as plot
b_plot = B6_dataframe.boxplot(column = ['ACC_x', 'ACC_y', 'ACC_z','BVP','EDA','Temp']) 
b_plot.plot()
plot.show()

###Box plot for 6B folder

# %% [markdown]
# ## 7A Folder visualization

# %%
path4 =  r"/content/drive/MyDrive/Colab Notebooks/Stress_dataset/7A"
acc_data = pd.DataFrame()
bvp_data = pd.DataFrame()
EDA_data = pd.DataFrame()
T_data = pd.DataFrame()

# Loop through all the subdirectories and files in the directory
for root, dirs, files in os.walk(path4):
    for file in files:
        # Check if the file is a CSV file
        if file.endswith('ACC.csv'):
          # Read the CSV file 
          file_path = os.path.join(root, file)
          temp_data = pd.read_csv(file_path, header=None, nrows=100) # 100 features per folder
          # Append the DataFrame 
          acc_data = acc_data.append(temp_data, ignore_index=True)

acc_data.columns = ['ACC_x', 'ACC_y', 'ACC_z']


for root, dirs, files in os.walk(path4):
    for file in files:
        # Check if the file is a CSV file
        if file.endswith('BVP.csv'):
            # Read the CSV file 
            file_path = os.path.join(root, file)
            temp_data = pd.read_csv(file_path, header=None, nrows=100)
            # Append the DataFrame 
            bvp_data = bvp_data.append(temp_data, ignore_index=True)

bvp_data.columns = ['BVP']


for root, dirs, files in os.walk(path4):
    for file in files:
        # Check if the file is a CSV file
        if file.endswith('EDA.csv'):
            # Read the CSV file 
            file_path = os.path.join(root, file)
            temp_data = pd.read_csv(file_path, header=None,nrows=100)
            # Append the DataFrame 
            EDA_data = EDA_data.append(temp_data, ignore_index=True)
               



EDA_data.columns = ['EDA']


# Loop through all the subdirectories and files in the directory
for root, dirs, files in os.walk(path4):
    for file in files:
        # Check if the file is a CSV file
        if file.endswith('TEMP.csv'):
            # Read the CSV file 
            file_path = os.path.join(root, file)
            temp_data = pd.read_csv(file_path, header=None,nrows=100)
            # Append the DataFrame 
            T_data = T_data.append(temp_data, ignore_index=True)

T_data.columns = ['Temp']

A7_dataframe =pd.DataFrame()
A7_dataframe = pd.concat([acc_data, bvp_data, EDA_data, T_data], axis=1) # merging features
A7_dataframe = A7_dataframe.fillna(A7_dataframe.median())
from sklearn.preprocessing import Normalizer
A7_col_names = list(A7_dataframe.columns)
A7_dataframe = Normalizer().fit_transform(A7_dataframe)
A7_dataframe = pd.DataFrame(A7_dataframe, columns=A7_col_names)

# Imports
import matplotlib.pyplot as plot
b_plot = A7_dataframe.boxplot(column = ['ACC_x', 'ACC_y', 'ACC_z','BVP','EDA','Temp']) 
b_plot.plot()
plot.show()

###Box plot for 6B folder

# %% [markdown]
# ## Reading all Folder

# %%
path =  r"/content/drive/MyDrive/Colab Notebooks/Stress_dataset"
acc_data = pd.DataFrame()
bvp_data = pd.DataFrame()
EDA_data = pd.DataFrame()
T_data = pd.DataFrame()

# extract ACC features
# Create an empty DataFrame to store the data
acc_data = pd.DataFrame()

# Loop through all the subdirectories and files in the directory
for root, dirs, files in os.walk(path):
    for file in files:
        # Check if the file is a CSV file
        if file.endswith('ACC.csv'):
          # Read the CSV file 
          file_path = os.path.join(root, file)
          temp_data = pd.read_csv(file_path, header=None, nrows=100) # 100 features per folder
          # Append the DataFrame 
          acc_data = acc_data.append(temp_data, ignore_index=True)

acc_data.columns = ['ACC_x', 'ACC_y', 'ACC_z']
acc_data=acc_data.iloc[1:2667,:]

# Loop through all the subdirectories and files in the directory
for root, dirs, files in os.walk(path):
    for file in files:
        # Check if the file is a CSV file
        if file.endswith('BVP.csv'):
            # Read the CSV file 
            file_path = os.path.join(root, file)
            temp_data = pd.read_csv(file_path, header=None, nrows=100)
            # Append the DataFrame 
            bvp_data = bvp_data.append(temp_data, ignore_index=True)

bvp_data.columns = ['BVP']
bvp_data=bvp_data.iloc[1:2667,:]

for root, dirs, files in os.walk(path):
    for file in files:
        # Check if the file is a CSV file
        if file.endswith('EDA.csv'):
            # Read the CSV file 
            file_path = os.path.join(root, file)
            temp_data = pd.read_csv(file_path, header=None,nrows=100)
            # Append the DataFrame 
            EDA_data = EDA_data.append(temp_data, ignore_index=True)
               
EDA_data.columns = ['EDA']
EDA_data=EDA_data.iloc[1:2667,:]

# Loop through all the subdirectories and files in the directory
for root, dirs, files in os.walk(path):
    for file in files:
        # Check if the file is a CSV file
        if file.endswith('TEMP.csv'):
            # Read the CSV file 
            file_path = os.path.join(root, file)
            temp_data = pd.read_csv(file_path, header=None,nrows=100)
            # Append the DataFrame 
            T_data = T_data.append(temp_data, ignore_index=True)
               
T_data.columns = ['Temp']
T_data=T_data.iloc[1:2667,:]

# %%
Final_dataframe =pd.DataFrame()
Final_dataframe = pd.concat([acc_data, bvp_data, EDA_data, T_data], axis=1) # merging features

# %%
Final_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 1 to 2666
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ACC_x   2666 non-null   float64
#  1   ACC_y   2666 non-null   float64
#  2   ACC_z   2666 non-null   float64
#  3   BVP     2666 non-null   float64
#  4   EDA     2666 non-null   float64
#  5   Temp    2666 non-null   float64
# dtypes: float64(6)
# memory usage: 125.1 KB

# %%
Final_dataframe.describe()
# Out:
#               ACC_x         ACC_y         ACC_z           BVP           EDA  \
# count  2.666000e+03  2.666000e+03  2.666000e+03  2.666000e+03  2.666000e+03
# mean   1.551958e+07  1.551961e+07  1.551962e+07  1.551963e+07  1.551961e+07
# std    1.564154e+08  1.564154e+08  1.564154e+08  1.564154e+08  1.564154e+08
# min   -1.280000e+02 -7.200000e+01 -9.700000e+01 -5.498500e+02  0.000000e+00
# 25%   -5.600000e+01 -9.000000e+00 -2.300000e+01  0.000000e+00  3.331100e-02
# 50%   -4.900000e+01  6.000000e+00  8.000000e+00  1.009000e+01  2.920910e-01
# 75%   -1.700000e+01  1.600000e+01  4.000000e+01  7.414000e+01  6.026700e-01
# max    1.603315e+09  1.603315e+09  1.603315e+09  1.603315e+09  1.603315e+09
#
#                Temp
# count  2.666000e+03
# mean   1.551964e+07
# std    1.564154e+08
# min    4.000000e+00
# 25%    2.621000e+01
# 50%    3.105000e+01
# 75%    3.243000e+01
# max    1.603315e+09

# %%
col_names = list(Final_dataframe.columns)
dataframe = pd.DataFrame(Final_dataframe, columns=col_names)
fig, (ax1) = plt.subplots(ncols=1)
ax1.set_title('Before Normaliation')

sns.kdeplot(Final_dataframe['Temp'], ax=ax1)
sns.kdeplot(Final_dataframe['ACC_x'], ax=ax1)
sns.kdeplot(Final_dataframe['ACC_y'], ax=ax1)
sns.kdeplot(Final_dataframe['ACC_z'], ax=ax1)
sns.kdeplot(Final_dataframe['EDA'], ax=ax1)
sns.kdeplot(Final_dataframe['BVP'], ax=ax1)
# Out:
# <Axes: title={'center': 'Before Normaliation'}, xlabel='Temp', ylabel='Density'>

# %%
# Percentage of missing values in each dataframe along with visualization
total = Final_dataframe.isnull().sum().sort_values(ascending=False)
percent = Final_dataframe.isnull().sum()/Final_dataframe.isnull().count().sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
#        Total  Percent
# ACC_x      0      0.0
# ACC_y      0      0.0
# ACC_z      0      0.0
# BVP        0      0.0
# EDA        0      0.0
# Temp       0      0.0

# %%
from sklearn.preprocessing import Normalizer

Final_dataframe = Normalizer().fit_transform(Final_dataframe)
Final_dataframe = pd.DataFrame(Final_dataframe, columns=col_names)
Final_dataframe
# Out:
#          ACC_x     ACC_y     ACC_z       BVP       EDA      Temp
# 0     0.377124  0.377124  0.377124  0.754247  0.047140  0.047140
# 1    -0.778822  0.222520  0.375503 -0.000000  0.000000  0.450465
# 2    -0.778783  0.222510  0.375485 -0.000000  0.009909  0.450443
# 3    -0.778756  0.222502  0.375472 -0.000000  0.012977  0.450427
# 4    -0.778786  0.222510  0.375486 -0.000000  0.009592  0.450444
# ...        ...       ...       ...       ...       ...       ...
# 2661 -0.410984  0.020048  0.491176  0.697571  0.001554  0.320668
# 2662 -0.398019  0.029123  0.475681  0.719734  0.001343  0.310552
# 2663 -0.383845  0.028086  0.458742  0.742787  0.001259  0.299493
# 2664 -0.374927  0.035707  0.437415  0.765030  0.001132  0.285570
# 2665 -0.355024  0.033812  0.414195  0.792549  0.001126  0.270410
#
# [2666 rows x 6 columns]

# %%
#Correlation map to see how features are correlated with SalePrice
corrmat = Final_dataframe.corr()
plt.subplots(figsize=(12,9))
sns.heatmap(corrmat, vmax=0.9, square=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
fig, (ax1) = plt.subplots(ncols=1)
ax1.set_title('After Normaliation')

sns.kdeplot(Final_dataframe['Temp'], ax=ax1)
sns.kdeplot(Final_dataframe['ACC_x'], ax=ax1)
sns.kdeplot(Final_dataframe['ACC_y'], ax=ax1)
sns.kdeplot(Final_dataframe['ACC_z'], ax=ax1)
sns.kdeplot(Final_dataframe['EDA'], ax=ax1)
# Out:
# <Axes: title={'center': 'After Normaliation'}, xlabel='Temp', ylabel='Density'>

# %%
#pd.plotting.scatter_matrix(Final_dataframe.loc[:,:], diagonal="kde",figsize=(20,15))
fig = pd.plotting.scatter_matrix(Final_dataframe,figsize=(20,15))
plt.show()

# %%
path =  r"/content/drive/MyDrive/Colab Notebooks/Stress_dataset"
HR_data = pd.DataFrame()
  # Load and Read all the subdirectories and directory
for root, dirs, files in os.walk(path):
    for file in files:
    # Check if the file is a CSV file
      if file.endswith('HR.csv'):
    # Read the CSV file 
        file_path = os.path.join(root, file)
        tdf = os.path.basename(os.path.dirname(file_path))
        temp_data = pd.read_csv(file_path, header=None, nrows=100) # 100 samples per file
        # Append the DataFrame to the main DataFrame
        HR_data = HR_data.append(temp_data, ignore_index=True)
HR_data.columns = ['HR']
print(HR_data)
# Out:
#                 HR
# 0     1.587212e+09
# 1     1.000000e+00
# 2     4.900000e+01
# 3     4.900000e+01
# 4     5.800000e+01
# ...            ...
# 2661  1.051300e+02
# 2662  1.042800e+02
# 2663  1.034700e+02
# 2664  1.026800e+02
# 2665  1.018800e+02
#
# [2666 rows x 1 columns]

# %%
HR_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HR      2666 non-null   float64
# dtypes: float64(1)
# memory usage: 21.0 KB

# %%
# labels from HR data

labels = HR_data
labels.columns = ['label'] 
labels.label[labels.label > 100] = 1
labels.label[labels.label < 60] = 1
labels.label[labels.label > 1] = 0
labels
# Out:
#       label
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
# ...     ...
# 2661    1.0
# 2662    1.0
# 2663    1.0
# 2664    1.0
# 2665    1.0
#
# [2666 rows x 1 columns]

# %%
y = labels
x =Final_dataframe

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
y_test
# Out:
#       label
# 1721    0.0
# 2280    0.0
# 1626    0.0
# 2263    0.0
# 1317    0.0
# ...     ...
# 2151    0.0
# 1931    0.0
# 530     1.0
# 245     0.0
# 1012    0.0
#
# [800 rows x 1 columns]

# %%
x_test
# Out:
#          ACC_x     ACC_y     ACC_z       BVP       EDA      Temp
# 1721  0.184942 -0.028453  0.882033  0.009389  0.000510  0.432338
# 2280 -0.066046  0.030271  0.151355  0.983777  0.000620  0.063211
# 1626 -0.121481 -0.728887  0.593908  0.032395  0.000000  0.316526
# 2263 -0.214906  0.039797  0.445731  0.848878  0.000000  0.181556
# 1317 -0.851441  0.265203 -0.097706 -0.000698  0.002522  0.441772
# ...        ...       ...       ...       ...       ...       ...
# 2151 -0.613770 -0.073652 -0.564668  0.442651  0.005438  0.321002
# 1931 -0.205216  0.102608  0.879496  0.074171  0.003061  0.410285
# 530   0.801063 -0.267021 -0.400531  0.065717  0.000095  0.349649
# 245  -0.715157  0.082518 -0.481356  0.201482  0.008905  0.457563
# 1012 -0.862362  0.201218 -0.071864  0.000144  0.008366  0.458921
#
# [800 rows x 6 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train, y_train)
y_pred = dtc.predict(x_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[632  31]
#  [ 42  95]]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.95      0.95       663
#          1.0       0.75      0.69      0.72       137
#
#     accuracy                           0.91       800
#    macro avg       0.85      0.82      0.83       800
# weighted avg       0.91      0.91      0.91       800

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)
y_pred = rfc.predict(x_test)


print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[651  12]
#  [ 41  96]]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.98      0.96       663
#          1.0       0.89      0.70      0.78       137
#
#     accuracy                           0.93       800
#    macro avg       0.91      0.84      0.87       800
# weighted avg       0.93      0.93      0.93       800
